# %% [markdown]
# <a href="https://colab.research.google.com/github/UtkarshRasal/deep_learning/blob/master/basic_neural_networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic Neural Network Model

# %% [markdown]
# ![sieci-neuronowe-grafika-1024x759.png](data:image/png;base64,...)
